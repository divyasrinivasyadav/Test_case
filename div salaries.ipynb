# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/pavankadari/Downloads/Sf_Salaries.csv")
data
# Out:
# C:\Users\pavankadari\AppData\Local\Temp\ipykernel_28280\2423728089.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("C:/Users/pavankadari/Downloads/Sf_Salaries.csv")
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
y=data.loc[data['BasePay']=="Not Provided"]
y
# Out:
#             Id  EmployeeName      JobTitle       BasePay   OvertimePay  \
# 148646  148647  Not provided  Not provided  Not Provided  Not Provided
# 148650  148651  Not provided  Not provided  Not Provided  Not Provided
# 148651  148652  Not provided  Not provided  Not Provided  Not Provided
# 148652  148653  Not provided  Not provided  Not Provided  Not Provided
#
#             OtherPay      Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148646  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148650  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148651  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148652  Not Provided  Not Provided       0.0               0.0  2014    NaN
#
#                Agency Status
# 148646  San Francisco    NaN
# 148650  San Francisco    NaN
# 148651  San Francisco    NaN
# 148652  San Francisco    NaN

# %%
data.BasePay.unique()
# Out:
# array([167411.18, 155966.02, 212739.13, ..., '6.04', '15.50',
#        'Not Provided'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
import numpy as np

# %%
#what is the highest amount of overtime pay in dataset
data['OvertimePay']=pd.to_numeric(data['OvertimePay'],errors='coerce')
highest_payment=data['OvertimePay'].max()
highest_payment
# Out:
# 245131.88

# %%
job_title= data.loc[data['EmployeeName']=="JOSEPH DRISCOLL",'JobTitle'].iloc[0]
job_title
# Out:
# 'CAPTAIN, FIRE SUPPRESSION'

# %%
data['BasePay']=data['BasePay'].replace('Not Provided','NaN')

# %%
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
data['OtherPay']=data['OtherPay'].replace('Not Provided',"NaN")

# %%
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
data['Benefits']=data['Benefits'].replace('Not Provided','NaN')

# %%
data['JobTitle']=data['JobTitle'].replace('Not Provided','NaN')

# %%
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
person_details=data.loc[data['EmployeeName']=='JOSEPH DRISCOLL','Benefits']
Benefits=person_details.iloc[0]
person_details
# Out:
# 24    NaN
# Name: Benefits, dtype: object

# %%
#7
data['totalpay with benefits']=data['TotalPay'].astype(float)+data['Benefits'].astype(float)
highest_paid_person=data.loc[data['totalpay with benefits'].idxmax(),'EmployeeName']
print('the highest_paid _person(including benefits) is:',highest_paid_person)
# Out:
# the highest_paid _person(including benefits) is: David Shinn

# %%
#8
data['totalpay with benefits']=data['TotalPay'].astype(float)+data['Benefits'].astype(float)
lowest_paid_person2=data.loc[data['totalpay with benefits'].idxmin(),'EmployeeName']
print('the lowest_paid _person(including benefits) is:',lowest_paid_person2)
# Out:
# the lowest_paid _person(including benefits) is: Joe Lopez

# %%
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1791, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1790 try:
# -> 1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    1794         how,
#    1795         axis=data.ndim - 1,
#    1796         min_count=min_count,
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# ...

# %%
#10
Unique_Job_Tiles=data['JobTitle'].nunique()

# %%
Unique_Job_Tiles
# Out:
# 2159

# %%
#11
filtered_data1=data[data['JobTitle']!='Not provided']
top_five_Job_Title=filtered_data1['JobTitle'].value_counts().head(5)
print(" the top five jobs are:",top_five_Job_Title)
# Out:
#  the top five jobs are: Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
data['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
