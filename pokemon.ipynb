# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:/Users/pavankadari/Downloads/Pokemon.csv")

# %%
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed
# ...

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
column_names=data.columns
#check thecolumns for dataframe

# %%
print(column_names)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#check the shape of the dataframe
shape=data.shape
print(shape)
# Out:
# (800, 13)

# %%
#check the statistical information about dataframe
statistic=data.describe()
print(statistic)
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
#how many pokemon are legendary
legendary=data[data['Name']==True]
print(legendary)
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
#legendary pokemon by type
legendary_type=data[data['Type 1']==True].groupby('Type 1')['Name'].count()
print(legendary_type)
# Out:
# Series([], Name: Name, dtype: int64)

# %%
#what are the most common types of pokemon
types=data[['Type 1','Type 2']].stack()
types
# Out:
# 0    Type 1      Grass
#      Type 2     Poison
# 1    Type 1      Grass
#      Type 2     Poison
# 2    Type 1      Grass
#                 ...
# 797  Type 2      Ghost
# 798  Type 1    Psychic
#      Type 2       Dark
# 799  Type 1       Fire
#      Type 2      Water
# Length: 1214, dtype: object

# %%
type
type_counts=types.value_counts()
type_counts
# Out:
# Water       126
# Normal      102
# Flying      101
# Grass        95
# Psychic      90
# Bug          72
# Ground       67
# Fire         64
# Poison       62
# Rock         58
# Fighting     53
# Dark         51
# Dragon       50
# Electric     50
# Steel        49
# Ghost        46
# Fairy        40
# Ice          38
# dtype: int64

# %%
print(type_counts.head())
# Out:
# Water      126
# Normal     102
# Flying     101
# Grass       95
# Psychic     90
# dtype: int64

# %%
#cleaning the dataset
data.dropna()
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data.drop_duplicates()
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
#How many Pokémon are legendary?
pokemon=data[data['Legendary']==True].shape[0]
pokemon
# Out:
# 65

# %%
#How many Pokémon are legendary?
pokemon=data.groupby('Type 1').count()['Legendary']
pokemon
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Legendary, dtype: int64

# %%
#Legendary Pokémon by fighter stats?
pokemon=data[data['Legendary']][['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Generation','Legendary']]
pokemon
# Out:
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156   90      85      100       95      125     85           1       True
# 157   90      90       85      125       90    100           1       True
# 158   90     100       90      125       85     90           1       True
# 162  106     110       90      154       90    130           1       True
# 163  106     190      100      154      100    130           1       True
# ..   ...     ...      ...      ...      ...    ...         ...        ...
# 795   50     100      150      100      150     50           6       True
# 796   50     160      110      160      110    110           6       True
# 797   80     110       60      150      130     70           6       True
# 798   80     160       60      170      130     80           6       True
# 799   80     110      120      130       90     70           6       True
#
# [65 rows x 8 columns]

# %%
#How are Pokemon numbers distributed across generations?
pokemon=data.groupby('Generation').count()
pokemon
# Out:
#               #  Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Generation
# 1           166   166     166      78    166  166     166      166      166
# 2           106   106     106      55    106  106     106      106      106
# 3           160   160     160      82    160  160     160      160      160
# 4           121   121     121      67    121  121     121      121      121
# 5           165   165     165      82    165  165     165      165      165
# 6            82    82      82      50     82   82      82       82       82
#
#             Sp. Def  Speed  Legendary
# Generation
# 1               166    166        166
# 2               106    106        106
# 3               160    160        160
# 4               121    121        121
# 5               165    165        165
# 6                82     82         82

# %%
#What are the most common types of Pokemon?
pokemom=pd.concat([data['Type 1'],data['Type 2']]).value_counts().head()
pokemon
# Out:
#               #  Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Generation
# 1           166   166     166      78    166  166     166      166      166
# 2           106   106     106      55    106  106     106      106      106
# 3           160   160     160      82    160  160     160      160      160
# 4           121   121     121      67    121  121     121      121      121
# 5           165   165     165      82    165  165     165      165      165
# 6            82    82      82      50     82   82      82       82       82
#
#             Sp. Def  Speed  Legendary
# Generation
# 1               166    166        166
# 2               106    106        106
# 3               160    160        160
# 4               121    121        121
# 5               165    165        165
# 6                82     82         82

# %%
#What are the strongest and weakest Pokemon?
strongest=data.loc[data['Total'].idxmax(),'Name']
weakest=data.loc[data['Total'].idxmin(),'Name']
print(strongest)
print(weakest)
# Out:
# MewtwoMega Mewtwo X
# Sunkern

# %%
#what are the strongest and weakest pokemon species
strongest=data.sort_values('Total',ascending=False)
weakest=data.sort_values('Total',ascending=True)
print(strongest[['Total','Name']])
print(weakest[['Total','Name']])
# Out:
#      Total                   Name
# 426    780  RayquazaMega Rayquaza
# 164    780    MewtwoMega Mewtwo Y
# 163    780    MewtwoMega Mewtwo X
# 422    770    KyogrePrimal Kyogre
# 424    770  GroudonPrimal Groudon
# ..     ...                    ...
# 13     195               Caterpie
# 288    195                Wurmple
# 446    194              Kricketot
# 322    190                Azurill
# 206    180                Sunkern
#
# [800 rows x 2 columns]
#      Total                   Name
# 206    180                Sunkern
# 322    190                Azurill
# 446    194              Kricketot
# 288    195                Wurmple
# 16     195                 Weedle
# ..     ...                    ...
# 424    770  GroudonPrimal Groudon
# 422    770    KyogrePrimal Kyogre
# 164    780    MewtwoMega Mewtwo Y
# 426    780  RayquazaMega Rayquaza
# 163    780    MewtwoMega Mewtwo X
#
# [800 rows x 2 columns]

# %%
#Do any types of Pokemon excel at certain statistics over others?
pokemon=data.groupby('Type 1')[['Attack','Defense','Speed','Sp. Atk','Sp. Def']].mean()
strongest=pokemon.idxmax()
print(strongest)
# Out:
# Attack      Dragon
# Defense      Steel
# Speed       Flying
# Sp. Atk    Psychic
# Sp. Def     Dragon
# dtype: object

# %%
#Are any of the statistics correlated?
correlation_matrix=data[['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']].corr()

print(correlation_matrix)
# Out:
#                HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# Attack   0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# Defense  0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# Sp. Atk  0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# Sp. Def  0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# Speed    0.175952  0.381240  0.015227  0.473018  0.259133  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
#Create a training/test split?

from sklearn.model_selection import train_test_split

features=data[['HP','Attack','Defense','Sp. Atk','Sp. Def','Sp. Atk','Sp. Def','Speed']]#specify the features and target variable 
target=data['Type 1']

X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=42)#split the data into training and test sets

print("Training set size:",len(X_train))
print("Test set size:",len(X_test))
# Out:
# Training set size: 640
# Test set size: 160

# %%
#split the data into train and model sets?
from sklearn.model_selection import train_test_split

features=data[['HP','Attack','Defense','Sp. Atk','Sp. Def','Sp. Atk','Sp. Def','Speed']]#specify the features and target variable 
target=data['Type 1']

X_train,X_model,y_train,y_model=train_test_split(features,target,test_size=0.2,random_state=42)#split the data into training and model sets

print("Training set size:",len(X_train))
print("model set size:",len(X_model))
# Out:
# Training set size: 640
# model set size: 160

# %%
X=data[['HP','Attack','Defense','Sp. Atk','Sp. Def','Sp. Atk','Sp. Def','Speed']]#specify the features and target variable 
y=data['Type 1']

X_train,X_model,y_train,y_model=train_test_split(X,y,test_size=0.2,random_state=101)

from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()

model.fit(X_train,y_train)
# Out:
# C:\Users\pavankadari\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array(['Water', 'Psychic', 'Water', 'Electric', 'Normal', 'Bug', 'Water',
#        'Rock', 'Water', 'Rock', 'Normal', 'Normal', 'Psychic', 'Water',
#        'Steel', 'Water', 'Psychic', 'Water', 'Normal', 'Bug', 'Rock',
#        'Rock', 'Water', 'Psychic', 'Normal', 'Normal', 'Normal', 'Water',
#        'Water', 'Water', 'Psychic', 'Psychic', 'Normal', 'Water', 'Water',
#        'Psychic', 'Water', 'Water', 'Dragon', 'Normal', 'Bug', 'Normal',
#        'Water', 'Steel', 'Normal', 'Psychic', 'Water', 'Normal', 'Bug',
#        'Electric', 'Water', 'Electric', 'Water', 'Water', 'Bug', 'Water',
#        'Water', 'Steel', 'Normal', 'Water', 'Water', 'Psychic', 'Normal',
#        'Psychic', 'Normal', 'Psychic', 'Water', 'Water', 'Psychic',
#        'Water', 'Water', 'Water', 'Rock', 'Ground', 'Normal', 'Water',
#        'Water', 'Ground', 'Ground', 'Normal', 'Electric', 'Bug', 'Normal',
#        'Water', 'Normal', 'Water', 'Bug', 'Electric', 'Normal', 'Normal',
# ...

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.2125
